# %%
from random import randint
import matplotlib.pyplot as plt
l1 = [randint(0,50) 
      for i in range(50)]

fig, axs = plt.subplots(
    2, 1, figsize=(15, 15))
plt.plot(l1)

fig, axs = plt.subplots(
    2, 2)
fig.set_figheight(30)
fig.set_figwidth(30)
plt.plot(l1)

plt.show()
