# %%
from pathlib import Path

p = Path('./')

d = [f.name for 
     f in p.iterdir()
     if f.is_dir()]
print(d)
# Out:
# ['144 How to remove (SQUEEZE) ALL whitespace from Python string.ipynb', '242 Create a list with numbers between 2 values in Python #shorts.ipynb', '095 How to flush the output of Python print function.ipynb', '191 makedir -p functionality in Python.ipynb', '006 How to execute a system command or run a program in Python #shorts.ipynb', '070 How to append to a file in Python.ipynb', '104 Put the Legend Outside a Python Matplotlib plot.ipynb', '079 How to pretty print a JSON file in Python #shorts.ipynb', "003 Python's ternary conditional operator #shorts.ipynb", '055 How to print in Python without a newline or space.ipynb', '224 Update your version of pip #shorts.ipynb', '082 Declare a custom Python exception.ipynb', "179 Python's equivalent of && (logical and) statement.ipynb", '238 % (modulus) operator in Python #shorts.ipynb', '184 Pip install from GitHub repo branch.ipynb', '125 How to drop Pandas DataFrame rows with NaN values in specific column #shorts.ipynb', '024 How to add new
# ...
