# %%
python -m pip freeze
# Out:
# anyio==3.6.2
# appnope==0.1.3
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arrow==1.2.3
# asttokens==2.2.1
# attrs==22.2.0
# backcall==0.2.0
# beautifulsoup4==4.11.1
# bleach==5.0.1
# cffi==1.15.1
# colorama==0.4.6
# comm==0.1.2
# contourpy==1.0.6
# cycler==0.11.0
# debugpy==1.6.4
# decorator==5.1.1
# defusedxml==0.7.1
# entrypoints==0.4
# executing==1.2.0
# fastjsonschema==2.16.2
# fonttools==4.38.0
# fqdn==1.5.1
# grapheme==0.6.0
# idna==3.4
# ipykernel==6.20.0
# ipython==8.7.0
# ipython-genutils==0.2.0
# ipywidgets==8.0.4
# isoduration==20.11.0
# jedi==0.18.2
# Jinja2==3.1.2
# jsonpointer==2.3
# jsonschema==4.17.3
# jupyter==1.0.0
# jupyter-console==6.4.4
# jupyter-events==0.5.0
# jupyter_client==7.4.8
# jupyter_core==5.1.1
# jupyter_server==2.0.5
# jupyter_server_terminals==0.4.3
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==3.0.5
# kiwisolver==1.4.4
# MarkupSafe==2.1.1
# matplotlib==3.6.2
# matplotlib-inline==0.1.6
# mistune==2.0.4
# nbclassic==0.4.8
# ...

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# /Users/willbunker/.pyenv/versions/3.11.1/lib/python3.11/pkgutil.py:92: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# /Users/willbunker/.pyenv/versions/3.11.1/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 002 What does if __name__ == "__main__": do aifc                inspect             quopri
# 040_terminal_print  antigravity         io                  random
# 143 Get the data received in Flask request anyio               ipaddress           re
# 146_ThreadPoolExecutor appnope             ipykernel           readline
# 159_print_pandas    argon2              ipykernel_launcher  reprlib
# 211 Get full path of current files directory in Python #shorts argparse            ipython_genutils    resource
# ...
