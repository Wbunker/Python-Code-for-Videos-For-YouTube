# %%
from matplotlib import pyplot as plt

x = [1, 2, 3]
y = [1, 4, 9]

fig = plt.figure()

plt.plot(x, y)

fig.suptitle(
    'squares',
    fontsize=20)
plt.xlabel(
    'x',
    fontsize=15)
plt.ylabel(
    'x^2',
    fontsize=15
)

plt.show()
