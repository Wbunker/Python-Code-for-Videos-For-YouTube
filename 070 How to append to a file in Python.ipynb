# %% [markdown]
# # Use the mode a (append) when opening the file

# %%
import random

with open('data/randomints.txt', mode='a') as file:
    file.write(str(random.randint(1,1000)))

# %% [markdown]
# # Let's Dig a Little Deeper
#
# https://docs.python.org/3/library/functions.html#open
#
# ![Screenshot_20220919_074234.png](attachment:Screenshot_20220919_074234.png)
