# %% [markdown]
# # Python has a built in profiler called cProfile

# %%
! python -m cProfile modules/find_subdirectories.py /home/bunker/consulting/
# Out:
#          11606312 function calls (10924372 primitive calls) in 5.618 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       9/1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:1002(_find_and_load)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:112(release)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:152(__init__)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:156(__enter__)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:160(__exit__)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:166(_get_module_lock)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:185(cb)
# ...
